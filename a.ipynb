# %%
import pandas as pd

# %%
a =  pd.read_csv('NEWTRANSFORMEDDATA.csv')
a
# Out:
#       Unnamed: 0  Dependents  tenure  OnlineSecurity  OnlineBackup  \
# 0              0           0       1               0             2
# 1              1           0      34               2             0
# 2              2           0       2               2             2
# 3              3           0      45               2             0
# 4              4           0       2               0             0
# ...          ...         ...     ...             ...           ...
# 7027        7038           1      24               2             0
# 7028        7039           1      72               0             2
# 7029        7040           1      11               2             0
# 7030        7041           0       4               0             0
# 7031        7042           0      66               2             0
#
#       DeviceProtection  TechSupport  Contract  PaperlessBilling  \
# 0                    0            0         0                 1
# ...
